# %%
import xlrd

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
filename = "GOOGL_price_data.xlsx"
wBook = xlrd.open_workbook(filename)
googl = wBook.sheet_by_name("GOOGL") # get the first (0th) sheet

# %%
googl

# %%
df = pd.read_excel(filename, sheet_name = 'GOOGL')
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-01-28  1090.069946  1093.369995  1074.609985  1079.859985
# 1   2019-01-29  1081.040039  1084.729980  1066.020020  1070.060059
# 2   2019-01-30  1077.359985  1099.520020  1076.640015  1097.989990
# 3   2019-01-31  1112.239990  1127.670044  1105.250000  1125.890015
# 4   2019-02-01  1122.290039  1134.400024  1114.250000  1118.619995
# ..         ...          ...          ...          ...          ...
# 248 2020-01-22  1489.729980  1500.579956  1482.660034  1483.869995
# 249 2020-01-23  1487.550049  1493.500000  1480.319946  1484.689941
# 250 2020-01-24  1492.819946  1494.199951  1463.180054  1466.170044
# 251 2020-01-27  1431.540039  1436.579956  1419.500000  1431.729980
# 252 2020-01-28  1441.739990  1454.359985  1430.369995  1452.530029
#
#        Adj Close   Volume
# 0    1079.859985  1466700
# 1    1070.060059   985200
# 2    1097.989990  1472600
# 3    1125.890015  2011600
# ...

# %%
dailyChanges = []
for i in range(1,googl.nrows): 
    openValues = googl.cell_value(i, 1) 
    closeValues = googl.cell_value(i,4)
    dailyChange = closeValues - openValues
    dailyChanges.append(dailyChange)
df["Daily Change"] = dailyChanges
df["Daily Return"] = df["Adj Close"].pct_change()

# %%
first = googl.cell_value(1, 1)  
first
# Out:
# 1090.069946

# %%
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-01-28  1090.069946  1093.369995  1074.609985  1079.859985
# 1   2019-01-29  1081.040039  1084.729980  1066.020020  1070.060059
# 2   2019-01-30  1077.359985  1099.520020  1076.640015  1097.989990
# 3   2019-01-31  1112.239990  1127.670044  1105.250000  1125.890015
# 4   2019-02-01  1122.290039  1134.400024  1114.250000  1118.619995
# ..         ...          ...          ...          ...          ...
# 248 2020-01-22  1489.729980  1500.579956  1482.660034  1483.869995
# 249 2020-01-23  1487.550049  1493.500000  1480.319946  1484.689941
# 250 2020-01-24  1492.819946  1494.199951  1463.180054  1466.170044
# 251 2020-01-27  1431.540039  1436.579956  1419.500000  1431.729980
# 252 2020-01-28  1441.739990  1454.359985  1430.369995  1452.530029
#
#        Adj Close   Volume  Daily Change  Daily Return
# 0    1079.859985  1466700    -10.209961           NaN
# ...

# %%
dailyReturns = df["Adj Close"].pct_change()
dailyReturns.plot(kind = 'hist')
whyDoesThisErrorYetStillWork.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-27a56746b99f> in <module>
#       1 dailyReturns = df["Adj Close"].pct_change()
#       2 dailyReturns.plot(kind = 'hist')
# ----> 3 whyDoesThisErrorYetStillWork.show()
#
# NameError: name 'whyDoesThisErrorYetStillWork' is not defined
